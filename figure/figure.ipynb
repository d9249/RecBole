# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0, 0.45, 0.1)
y = np.arange(0, 0.3, 0.1)

# Recall/Precision

# Time_1_ml-100k
plt.plot([0.3042,0.2994,0.2948,0.3116,0.3094,0.3136,0.2817,0.2966,0.2909,0.2678,0.2445,0.2681,0.2514,0.2062,0.1776,0.1925,0.1429,0.1614,0.1506,0.1387,0.1137,0.0572,0.0476], 
         [0.227,0.2264,0.223,0.2192,0.2191,0.218,0.2121,0.2119,0.2099,0.2001,0.1997,0.1935,0.188,0.1794,0.1521,0.1378,0.1319,0.1268,0.1239,0.1221,0.093,0.0599,0.0457], 'ro--')

# Time_2_ml-100k
plt.plot([0.3438,0.3457,0.3418,0.3219,0.3305,0.3324,0.32,0.3189,0.3089,0.3005,0.2883,0.2248,0.191,0.1536,0.2042,0.159,0.1831,0.1696,0.1679,0.1307,0.0605,0.0522,0.0522], 
         [0.2178,0.2138,0.2135,0.2079,0.2054,0.2042,0.2038,0.197,0.1875,0.1857,0.1816,0.1655,0.1466,0.1191,0.1168,0.1133,0.1132,0.112,0.1102,0.0888,0.0462,0.042,0.042], 'go--')

# Time_3_ml-100k
plt.plot([0.3669,0.3604,0.3587,0.358,0.3514,0.3563,0.3479,0.3328,0.3247,0.3314,0.3193,0.2789,0.1767,0.161,0.1238,0.1572,0.1643,0.1669,0.137,0.2002,0.0682,0.041,0.0396], 
         [0.1714,0.1658,0.1653,0.1652,0.1651,0.1614,0.1591,0.1558,0.1538,0.1536,0.1536,0.1465,0.0966,0.091,0.091,0.0895,0.0871,0.0861,0.0769,0.074,0.0456,0.0269,0.026], 'bo--')

# Time_4_ml-100k
plt.plot([0.3995,0.3822,0.378,0.3814,0.3659,0.3703,0.3557,0.3638,0.3585,0.3534,0.3525,0.2901,0.1989,0.1839,0.169,0.1829,0.1836,0.124,0.1634,0.221,0.0915,0.0426,0.0416], 
         [0.1658,0.1575,0.1555,0.1544,0.1519,0.1508,0.1493,0.1486,0.1461,0.1458,0.1413,0.1313,0.0944,0.0882,0.087,0.0856,0.0846,0.0818,0.0758,0.0652,0.0484,0.0229,0.0226], 'co--')

# Time_random_ml-100k
plt.plot([0.1894,0.1996,0.1941,0.1822,0.1796,0.169,0.1758,0.1818,0.1859,0.1537,0.1688,0.1723,0.1407,0.1527,0.1501,0.136,0.1311,0.0808,0.1006,0.0731,0.0559,0.0377,0.0268], 
[0.0724,0.0683,0.0674,0.0647,0.0649,0.0661,0.0645,0.0619,0.061,0.0624,0.0602,0.0579,0.0574,0.0548,0.0542,0.0531,0.0513,0.0458,0.0397,0.0293,0.0245,0.01970,0.0097], 'yo--')

plt.xlabel('eval/Recall@20')
plt.ylabel('eval/Precision@20')
# plt.show()
plt.savefig('figure_1.png', dpi=1200)

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0, 0.45, 0.1)
y = np.arange(0, 0.3, 0.1)

# Recall/Precision

# Time_1_ml-1m
plt.plot([0.2332,0.2175,0.2089,0.2079,0.2177,0.2189,0.2114,0.2025,0.1951,0.1941,0.1582,0.1267,0.1811,0.0942,0.0954,0.0953,0.0888,0.0886,0.064,0.029,0.0289,0.0289,0.0237], 
         [0.2744,0.2621,0.2588,0.2569,0.256,0.2546,0.249,0.2409,0.2369,0.2313,0.2186,0.1817,0.1722,0.1407,0.1404,0.14,0.1325,0.1307,0.0899,0.0634,0.0467,0.0467,0.041], 'ro--')

# Time_2_ml-1m
plt.plot([0.2625,0.2499,0.2378,0.2384,0.2386,0.2363,0.2272,0.2272,0.212,0.2005,0.2127,0.1623,0.1261,0.1048,0.1038,0.1014,0.0998,0.0995,0.0927,0.0316,0.0316,0.0288,0.0242], 
         [0.2604,0.2375,0.2455,0.2433,0.2353,0.2356,0.2368,0.2288,0.2172,0.2125,0.1705,0.1943,0.1585,0.1262,0.1264,0.126,0.122,0.1215,0.107,0.0405,0.0405,0.0386,0.0336], 'go--')

# Time_3_ml-1m
plt.plot([0.2856,0.2712,0.2635,0.2654,0.2642,0.2668,0.2542,0.2423,0.2373,0.2458,0.1935,0.1593,0.1379,0.1363,0.1138,0.1121,0.1111,0.1116,0.0837,0.0310,0.031,0.0221,0.0225], 
[0.2051,0.1992,0.1952,0.1861,0.1866,0.1846,0.1841,0.1825,0.1737,0.146,0.1537,0.1425,0.1228,0.1153,0.0964,0.0966,0.0966,0.0954,0.0658,0.0284,0.0284,0.0226,0.0206], 'bo--')

# Time_4_ml-1m
# plt.plot([], 
# [], 'co--')

# Time_random_ml-1m
# plt.plot([], 
# [], 'yo--')

plt.xlabel('eval/Recall@20')
plt.ylabel('eval/Precision@20')
# plt.show()
plt.savefig('figure_2.png', dpi=1200)

# %%
def time_convert(x):
    day = datetime.fromtimestamp(x).strftime('%Y-%m')
    return day

# %%
import numpy as np
import pandas as pd
from datetime import datetime

columns_name = ['user_id','item_id','rating','timestamp']
ml_1m_1_df = pd.read_csv("/home/RecBole/dataset/Train_1_ml-1m.inter",sep="\t", names = columns_name)        
ml_1m_1_df['DAY'] = ml_1m_1_df['timestamp'].apply(time_convert)
ml_1m_1_df = ml_1m_1_df.sort_values(by='DAY', ascending=True)

ml_1m_1_index = ml_1m_1_df['DAY'].value_counts().tolist()
ml_1m_1_etc = sum(ml_1m_1_index[3:-1])
ml_1m_1_index = ml_1m_1_index[0:3]
ml_1m_1_index.append(ml_1m_1_etc)

ml_1m_1_count = ml_1m_1_df['DAY'].value_counts().index.tolist()
ml_1m_1_count = ml_1m_1_count[0:3]
ml_1m_1_count.append('etc')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, ax = plt.subplots(figsize=(6, 3), subplot_kw=dict(aspect="equal"))

def func(pct, allvals):
    absolute = int(np.round(pct/100.*np.sum(allvals)))
    return f"{pct:.1f}%\n({absolute:d})"

wedges, texts, autotexts = ax.pie(ml_1m_1_index, 
                                  autopct=lambda pct: func(pct, ml_1m_1_index),
                                  textprops=dict(color="w"), 
                                  labeldistance=1.1, 
                                  labels=ml_1m_1_count
                                 )

ax.legend(wedges, ml_1m_1_count,
          title="Year/month",
          loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1))

plt.setp(autotexts, size=7, weight="bold")
ax.set_title("Train_1_ml-1m")
plt.savefig('Train_1_ml-1m.png', dpi=1200)

# %%
import numpy as np
import pandas as pd
from datetime import datetime

columns_name = ['user_id','item_id','rating','timestamp']
ml_1m_2_df = pd.read_csv("/home/RecBole/dataset/Train_2_ml-1m.inter",sep="\t", names = columns_name)        
ml_1m_2_df['DAY'] = ml_1m_2_df['timestamp'].apply(time_convert)
ml_1m_2_df = ml_1m_2_df.sort_values(by='DAY', ascending=True)

ml_1m_2_index = ml_1m_2_df['DAY'].value_counts().tolist()
ml_1m_2_etc = sum(ml_1m_2_index[3:-1])
ml_1m_2_index = ml_1m_2_index[0:3]
ml_1m_2_index.append(ml_1m_2_etc)

ml_1m_2_count = ml_1m_2_df['DAY'].value_counts().index.tolist()
ml_1m_2_count = ml_1m_2_count[0:3]
ml_1m_2_count.append('etc')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, ax = plt.subplots(figsize=(6, 3), subplot_kw=dict(aspect="equal"))

def func(pct, allvals):
    absolute = int(np.round(pct/100.*np.sum(allvals)))
    return f"{pct:.1f}%\n({absolute:d})"

wedges, texts, autotexts = ax.pie(ml_1m_2_index, 
                                  autopct=lambda pct: func(pct, ml_1m_2_index),
                                  textprops=dict(color="w"), 
                                  labeldistance=1.1, 
                                  labels=ml_1m_2_count
                                 )

ax.legend(wedges, ml_1m_2_count,
          title="Year/month",
          loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1))

plt.setp(autotexts, size=7, weight="bold")
ax.set_title("Train_2_ml-1m")
plt.savefig('Train_2_ml-1m.png', dpi=1200)

# %%
columns_name = ['user_id','item_id','rating','timestamp']
ml_1m_3_df = pd.read_csv("/home/RecBole/dataset/Train_3_ml-1m.inter",sep="\t", names = columns_name)        
ml_1m_3_df['DAY'] = ml_1m_3_df['timestamp'].apply(time_convert)
ml_1m_3_df = ml_1m_3_df.sort_values(by='DAY', ascending=True)

ml_1m_3_index = ml_1m_3_df['DAY'].value_counts().tolist()
ml_1m_3_etc = sum(ml_1m_3_index[3:-1])
ml_1m_3_index = ml_1m_3_index[0:3]
ml_1m_3_index.append(ml_1m_3_etc)

ml_1m_3_count = ml_1m_3_df['DAY'].value_counts().index.tolist()
ml_1m_3_count = ml_1m_3_count[0:3]
ml_1m_3_count.append('etc')

fig, ax = plt.subplots(figsize=(6, 3), subplot_kw=dict(aspect="equal"))

def func(pct, allvals):
    absolute = int(np.round(pct/100.*np.sum(allvals)))
    return f"{pct:.1f}%\n({absolute:d})"

wedges, texts, autotexts = ax.pie(ml_1m_3_index, 
                                  autopct=lambda pct: func(pct, ml_1m_3_index),
                                  textprops=dict(color="w"), 
                                  labeldistance=1.1, 
                                  labels=ml_1m_3_count
                                 )

ax.legend(wedges, ml_1m_3_count,
          title="Year/month",
          loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1))

plt.setp(autotexts, size=7, weight="bold")
ax.set_title("Train_3_ml-1m")
plt.savefig('Train_3_ml-1m.png', dpi=1200)

# %%
columns_name = ['user_id','item_id','rating','timestamp']
ml_1m_4_df = pd.read_csv("/home/RecBole/dataset/Train_4_ml-1m.inter",sep="\t", names = columns_name)        
ml_1m_4_df['DAY'] = ml_1m_4_df['timestamp'].apply(time_convert)
ml_1m_4_df = ml_1m_4_df.sort_values(by='DAY', ascending=True)

ml_1m_4_index = ml_1m_4_df['DAY'].value_counts().tolist()
ml_1m_4_etc = sum(ml_1m_4_index[3:-1])
ml_1m_4_index = ml_1m_4_index[0:3]
ml_1m_4_index.append(ml_1m_4_etc)

ml_1m_4_count = ml_1m_4_df['DAY'].value_counts().index.tolist()
ml_1m_4_count = ml_1m_4_count[0:3]
ml_1m_4_count.append('etc')

fig, ax = plt.subplots(figsize=(6, 3), subplot_kw=dict(aspect="equal"))

def func(pct, allvals):
    absolute = int(np.round(pct/100.*np.sum(allvals)))
    return f"{pct:.1f}%\n({absolute:d})"

wedges, texts, autotexts = ax.pie(ml_1m_4_index, 
                                  autopct=lambda pct: func(pct, ml_1m_4_index),
                                  textprops=dict(color="w"), 
                                  labeldistance=1.1, 
                                  labels=ml_1m_4_count
                                 )

ax.legend(wedges, ml_1m_4_count,
          title="Year/month",
          loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1))

plt.setp(autotexts, size=7, weight="bold")
ax.set_title("Train_4_ml-1m")
plt.savefig('Train_4_ml-1m.png', dpi=1200)

# %%
columns_name = ['user_id','item_id','rating','timestamp']
ml_1m_random_df = pd.read_csv("/home/RecBole/dataset/Train_random_ml-1m.inter",sep="\t", names = columns_name)        
ml_1m_random_df['DAY'] = ml_1m_random_df['timestamp'].apply(time_convert)
ml_1m_random_df = ml_1m_random_df.sort_values(by='DAY', ascending=True)

ml_1m_random_index = ml_1m_random_df['DAY'].value_counts().tolist()
ml_1m_random_etc = sum(ml_1m_random_index[3:-1])
ml_1m_random_index = ml_1m_random_index[0:3]
ml_1m_random_index.append(ml_1m_random_etc)

ml_1m_random_count = ml_1m_random_df['DAY'].value_counts().index.tolist()
ml_1m_random_count = ml_1m_random_count[0:3]
ml_1m_random_count.append('etc')

fig, ax = plt.subplots(figsize=(6, 3), subplot_kw=dict(aspect="equal"))

def func(pct, allvals):
    absolute = int(np.round(pct/100.*np.sum(allvals)))
    return f"{pct:.1f}%\n({absolute:d})"

wedges, texts, autotexts = ax.pie(ml_1m_random_index, 
                                  autopct=lambda pct: func(pct, ml_1m_random_index),
                                  textprops=dict(color="w"), 
                                  labeldistance=1.1, 
                                  labels=ml_1m_random_count
                                 )

ax.legend(wedges, ml_1m_random_count,
          title="Year/month",
          loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1))

plt.setp(autotexts, size=7, weight="bold")
ax.set_title("Train_random_ml-1m")
plt.savefig('Train_random_ml-1m.png', dpi=1200)

# %%
columns_name = ['user_id','item_id','rating','timestamp']
ml_100k_1_df = pd.read_csv("/home/RecBole/dataset/Custom_ml-100k_1.inter",sep="\t", names = columns_name)        
ml_100k_1_df['DAY'] = ml_100k_1_df['timestamp'].apply(time_convert)
ml_100k_1_df = ml_100k_1_df.sort_values(by='DAY', ascending=True)

ml_100k_1_index = ml_100k_1_df['DAY'].value_counts().tolist()
ml_100k_1_etc = sum(ml_100k_1_index[3:-1])
ml_100k_1_index = ml_100k_1_index[0:3]
ml_100k_1_index.append(ml_100k_1_etc)

ml_100k_1_count = ml_100k_1_df['DAY'].value_counts().index.tolist()
ml_100k_1_count = ml_100k_1_count[0:3]
ml_100k_1_count.append('etc')

fig, ax = plt.subplots(figsize=(6, 3), subplot_kw=dict(aspect="equal"))

def func(pct, allvals):
    absolute = int(np.round(pct/100.*np.sum(allvals)))
    return f"{pct:.1f}%\n({absolute:d})"

wedges, texts, autotexts = ax.pie(ml_100k_1_index, 
                                  autopct=lambda pct: func(pct, ml_100k_1_index),
                                  textprops=dict(color="w"), 
                                  labeldistance=1.1, 
                                  labels=ml_100k_1_count
                                 )

ax.legend(wedges, ml_100k_1_count,
          title="Year/month",
          loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1))

plt.setp(autotexts, size=7, weight="bold")
ax.set_title("Train_1_ml-100k")
plt.savefig('Train_1_ml-100k.png', dpi=1200)

# %%
columns_name = ['user_id','item_id','rating','timestamp']
ml_100k_2_df = pd.read_csv("/home/RecBole/dataset/Custom_ml-100k_2.inter",sep="\t", names = columns_name)        
ml_100k_2_df['DAY'] = ml_100k_2_df['timestamp'].apply(time_convert)
ml_100k_2_df = ml_100k_2_df.sort_values(by='DAY', ascending=True)

ml_100k_2_index = ml_100k_2_df['DAY'].value_counts().tolist()
ml_100k_2_etc = sum(ml_100k_2_index[3:-1])
ml_100k_2_index = ml_100k_2_index[0:3]
ml_100k_2_index.append(ml_100k_2_etc)

ml_100k_2_count = ml_100k_2_df['DAY'].value_counts().index.tolist()
ml_100k_2_count = ml_100k_2_count[0:3]
ml_100k_2_count.append('etc')

fig, ax = plt.subplots(figsize=(6, 3), subplot_kw=dict(aspect="equal"))

def func(pct, allvals):
    absolute = int(np.round(pct/100.*np.sum(allvals)))
    return f"{pct:.1f}%\n({absolute:d})"

wedges, texts, autotexts = ax.pie(ml_100k_2_index, 
                                  autopct=lambda pct: func(pct, ml_100k_2_index),
                                  textprops=dict(color="w"), 
                                  labeldistance=1.1, 
                                  labels=ml_100k_2_count
                                 )

ax.legend(wedges, ml_100k_2_count,
          title="Year/month",
          loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1))

plt.setp(autotexts, size=7, weight="bold")
ax.set_title("Train_2_ml-100k")
plt.savefig('Train_2_ml-100k.png', dpi=1200)

# %%
columns_name = ['user_id','item_id','rating','timestamp']
ml_100k_3_df = pd.read_csv("/home/RecBole/dataset/Custom_ml-100k_3.inter",sep="\t", names = columns_name)        
ml_100k_3_df['DAY'] = ml_100k_3_df['timestamp'].apply(time_convert)
ml_100k_3_df = ml_100k_3_df.sort_values(by='DAY', ascending=True)

ml_100k_3_index = ml_100k_3_df['DAY'].value_counts().tolist()
ml_100k_3_etc = sum(ml_100k_3_index[3:-1])
ml_100k_3_index = ml_100k_3_index[0:3]
ml_100k_3_index.append(ml_100k_3_etc)

ml_100k_3_count = ml_100k_3_df['DAY'].value_counts().index.tolist()
ml_100k_3_count = ml_100k_3_count[0:3]
ml_100k_3_count.append('etc')

fig, ax = plt.subplots(figsize=(6, 3), subplot_kw=dict(aspect="equal"))

def func(pct, allvals):
    absolute = int(np.round(pct/100.*np.sum(allvals)))
    return f"{pct:.1f}%\n({absolute:d})"

wedges, texts, autotexts = ax.pie(ml_100k_3_index, 
                                  autopct=lambda pct: func(pct, ml_100k_3_index),
                                  textprops=dict(color="w"), 
                                  labeldistance=1.1, 
                                  labels=ml_100k_3_count
                                 )

ax.legend(wedges, ml_100k_3_count,
          title="Year/month",
          loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1))

plt.setp(autotexts, size=7, weight="bold")
ax.set_title("Train_3_ml-100k")
plt.savefig('Train_3_ml-100k.png', dpi=1200)

# %%
columns_name = ['user_id','item_id','rating','timestamp']
ml_100k_4_df = pd.read_csv("/home/RecBole/dataset/Custom_ml-100k_4.inter",sep="\t", names = columns_name)        
ml_100k_4_df['DAY'] = ml_100k_4_df['timestamp'].apply(time_convert)
ml_100k_4_df = ml_100k_4_df.sort_values(by='DAY', ascending=True)

ml_100k_4_index = ml_100k_4_df['DAY'].value_counts().tolist()
ml_100k_4_etc = sum(ml_100k_4_index[3:-1])
ml_100k_4_index = ml_100k_4_index[0:3]
ml_100k_4_index.append(ml_100k_4_etc)

ml_100k_4_count = ml_100k_4_df['DAY'].value_counts().index.tolist()
ml_100k_4_count = ml_100k_4_count[0:3]
ml_100k_4_count.append('etc')

fig, ax = plt.subplots(figsize=(6, 3), subplot_kw=dict(aspect="equal"))

def func(pct, allvals):
    absolute = int(np.round(pct/100.*np.sum(allvals)))
    return f"{pct:.1f}%\n({absolute:d})"

wedges, texts, autotexts = ax.pie(ml_100k_4_index, 
                                  autopct=lambda pct: func(pct, ml_100k_4_index),
                                  textprops=dict(color="w"), 
                                  labeldistance=1.1, 
                                  labels=ml_100k_4_count
                                 )

ax.legend(wedges, ml_100k_4_count,
          title="Year/month",
          loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1))

plt.setp(autotexts, size=7, weight="bold")
ax.set_title("Train_4_ml-100k")
plt.savefig('Train_4_ml-100k.png', dpi=1200)

# %%
columns_name = ['user_id','item_id','rating','timestamp']
ml_100k_random_df = pd.read_csv("/home/RecBole/dataset/Custom_ml-100k_random.inter",sep="\t", names = columns_name)        
ml_100k_random_df['DAY'] = ml_100k_random_df['timestamp'].apply(time_convert)
ml_100k_random_df = ml_100k_random_df.sort_values(by='DAY', ascending=True)

ml_100k_random_index = ml_100k_random_df['DAY'].value_counts().tolist()
ml_100k_random_etc = sum(ml_100k_random_index[3:-1])
ml_100k_random_index = ml_100k_random_index[0:3]
ml_100k_random_index.append(ml_100k_random_etc)

ml_100k_random_count = ml_100k_random_df['DAY'].value_counts().index.tolist()
ml_100k_random_count = ml_100k_random_count[0:3]
ml_100k_random_count.append('etc')

fig, ax = plt.subplots(figsize=(6, 3), subplot_kw=dict(aspect="equal"))

def func(pct, allvals):
    absolute = int(np.round(pct/100.*np.sum(allvals)))
    return f"{pct:.1f}%\n({absolute:d})"

wedges, texts, autotexts = ax.pie(ml_100k_random_index, 
                                  autopct=lambda pct: func(pct, ml_100k_random_index),
                                  textprops=dict(color="w"), 
                                  labeldistance=1.1, 
                                  labels=ml_100k_random_count
                                 )

ax.legend(wedges, ml_100k_random_count,
          title="Year/month",
          loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1))

plt.setp(autotexts, size=7, weight="bold")
ax.set_title("Train_random_ml-100k")
plt.savefig('Train_random_ml-100k.png', dpi=1200)
