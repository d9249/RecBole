# %%
import pandas as pd

# df = pd.read_csv('/home/RecBole/dataset/ml-100k/movies.csv', encoding='latin-1')

item_df = pd.read_csv('ml-100k.item', sep='\t')

item_df.head()
# Out:
#    item_id:token movie_title:token_seq release_year:token  \
# 0              1             Toy Story               1995
# 1              2             GoldenEye               1995
# 2              3            Four Rooms               1995
# 3              4            Get Shorty               1995
# 4              5               Copycat               1995
#
#                class:token_seq
# 0  Animation Children's Comedy
# 1    Action Adventure Thriller
# 2                     Thriller
# 3          Action Comedy Drama
# 4         Crime Drama Thriller

# %%
user_df = pd.read_csv('ml-100k.user', sep='\t')

user_df.head()
# Out:
#    user_id:token  age:token gender:token occupation:token zip_code:token
# 0              1         24            M       technician          85711
# 1              2         53            F            other          94043
# 2              3         23            M           writer          32067
# 3              4         24            M       technician          43537
# 4              5         33            F            other          15213

# %%
inter_df = pd.read_csv('ml-100k.inter', sep='\t')

inter_df.head()
# Out:
#    user_id:token  item_id:token  rating:float  timestamp:float
# 0            196            242             3        881250949
# 1            186            302             3        891717742
# 2             22            377             1        878887116
# 3            244             51             2        880606923
# 4            166            346             1        886397596

# %%
item_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1682 entries, 0 to 1681
# Data columns (total 4 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   item_id:token          1682 non-null   int64
#  1   movie_title:token_seq  1682 non-null   object
#  2   release_year:token     1682 non-null   object
#  3   class:token_seq        1682 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 52.7+ KB

# %%
item_df.nunique()
# Out:
# item_id:token            1682
# movie_title:token_seq    1659
# release_year:token         73
# class:token_seq           216
# dtype: int64

# %%
# %matplotlib inline

from autoviz.AutoViz_Class import AutoViz_Class
import matplotlib.pyplot as plt
plt.style.use('dark_background')

AV = AutoViz_Class()

AV.AutoViz(
    filename='',
    dfte=item_df,
    depVar='item_df',
    verbose=2, # 0: 간단히 표시; 1: 자세히 표시; 2: 파일로 저장
    max_rows_analyzed=item_df.shape[0],
    max_cols_analyzed=item_df.shape[1])
# Out:
# Shape of your Data Set loaded: (1682, 4)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
# Data cleaning improvement suggestions. Complete them before proceeding to ML modeling.
# <style type="text/css">
# #T_4d7e3_row0_col0, #T_4d7e3_row0_col4, #T_4d7e3_row1_col5, #T_4d7e3_row2_col5, #T_4d7e3_row3_col5 {
#   background-color: #67000d;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_4d7e3_row0_col1, #T_4d7e3_row0_col6, #T_4d7e3_row1_col1, #T_4d7e3_row1_col6, #T_4d7e3_row2_col1, #T_4d7e3_row2_col6, #T_4d7e3_row3_col1, #T_4d7e3_row3_col6 {
#   font-family: Segoe UI;
# }
# ...

# %%
# %matplotlib inline

plt.style.use('dark_background')

AV = AutoViz_Class()

AV.AutoViz(
    filename='',
    dfte=user_df,
    depVar='user_df',
    verbose=2, # 0: 간단히 표시; 1: 자세히 표시; 2: 파일로 저장
    max_rows_analyzed=user_df.shape[0],
    max_cols_analyzed=user_df.shape[1])
# Out:
# Shape of your Data Set loaded: (943, 5)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
# Data cleaning improvement suggestions. Complete them before proceeding to ML modeling.
# <style type="text/css">
# #T_d84af_row0_col0, #T_d84af_row0_col4, #T_d84af_row4_col5 {
#   background-color: #67000d;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_d84af_row0_col1, #T_d84af_row0_col6, #T_d84af_row1_col1, #T_d84af_row1_col6, #T_d84af_row2_col1, #T_d84af_row2_col6, #T_d84af_row3_col1, #T_d84af_row3_col6, #T_d84af_row4_col1, #T_d84af_row4_col6 {
#   font-family: Segoe UI;
# }
# ...

# %%
# %matplotlib inline

plt.style.use('dark_background')

AV = AutoViz_Class()

AV.AutoViz(
    filename='',
    dfte=inter_df,
    depVar='inter_df',
    verbose=2, # 0: 간단히 표시; 1: 자세히 표시; 2: 파일로 저장
    max_rows_analyzed=inter_df.shape[0],
    max_cols_analyzed=inter_df.shape[1])
# Out:
# Shape of your Data Set loaded: (100000, 4)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
# Data cleaning improvement suggestions. Complete them before proceeding to ML modeling.
# <style type="text/css">
# #T_a7378_row0_col0, #T_a7378_row0_col4 {
#   background-color: #67000d;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_a7378_row0_col1, #T_a7378_row0_col6, #T_a7378_row1_col1, #T_a7378_row1_col6, #T_a7378_row2_col1, #T_a7378_row2_col6, #T_a7378_row3_col1, #T_a7378_row3_col6 {
#   font-family: Segoe UI;
# }
# ...
